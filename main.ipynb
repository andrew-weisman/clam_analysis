# %%
df
# Out:
#                        slide_id  process     status  seg_level  sthresh  \
# 0               0029468706.mrxs        0  processed          6       15
# 1               0042034876.mrxs        0  processed          6       15
# 2               0042711961.mrxs        0  processed          6       15
# 3               0042951302.mrxs        0  processed          6       15
# 4               0046877280.mrxs        0  processed          6       15
# 5               0047176089.mrxs        0  processed          6       15
# 6               0047953852.mrxs        0  processed          6       15
# 7               0048086809.mrxs        0  processed          6       15
# 8               0049547258.mrxs        0  processed          6       15
# 9               0054130784.mrxs        0  processed          6       15
# 10              0055483886.mrxs        0  processed          6       15
# 11              0057134497.mrxs        0  processed          6       15
# ...

# %%
import pandas as pd
file_list = ['/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_biopsy/process_list_autogen.csv',
             '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_resection/process_list_autogen.csv',
             '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-default_settings/process_list_autogen.csv',
             '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-pinyi/process_list_autogen.csv',
             '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-tcga/process_list_autogen.csv']
for file in file_list:
    print('\nOn file {}:'.format(file))
    df = pd.read_csv(filepath_or_buffer=file, sep=',', header=0, )
    df2 = df.drop(['slide_id', 'process', 'status'], axis='columns')
    for column in df2.columns:
        unique_vals = df2[column].unique()
        # if len(unique_vals) == 1:
        #     print('Column {} has only unique values of: {}'.format(column, unique_vals[0]))
        # else:
        #     print('Column {} does NOT have only unique values: {}'.format(column, unique_vals))
        if not len(unique_vals) == 1:
            print('Column {} does NOT have only unique values: {}'.format(column, unique_vals))
# Out:
# On file /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_biopsy/process_list_autogen.csv:
#
# On file /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_resection/process_list_autogen.csv:
#
# On file /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-default_settings/process_list_autogen.csv:
#
# On file /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-pinyi/process_list_autogen.csv:
# Column sthresh does NOT have only unique values: [ 1 15  2  5 10 55]
# Column close does NOT have only unique values: [185   2  30  90  20  80 250 120  50 100  85]
# Column a_t does NOT have only unique values: [ 1. 25.]
# Column a_h does NOT have only unique values: [1. 4.]
#
# On file /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-tcga/process_list_autogen.csv:

# %%
input_files = ['/home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/bwh_biopsy.csv',
               '/home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/bwh_resection.csv',
               '/home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/tcga.csv']
output_files = ['/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_biopsy/process_list_autogen.csv',
                '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_resection/process_list_autogen.csv',
                '/home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-tcga/process_list_autogen.csv']
for input_file, output_file in zip(input_files, output_files):
    print(input_file, output_file)
    df = pd.read_csv(filepath_or_buffer=output_file, sep=',', header=0, )
    df2 = df.drop(['slide_id', 'process', 'status'], axis='columns')
    output_series = df2.loc[0,:]
    input_series = pd.read_csv(filepath_or_buffer=input_file, sep=',', header=0, ).loc[0,:]
    # for index in (set(input_series.index) - set(output_series.index)):
    #     print('Value of {}: {}'.format(index, input_series[index]))
    for index in output_series.index:
        in_val = input_series[index]
        out_val = output_series[index]
        if in_val != out_val:
            print('The {} value has differing values for input and output: {}'.format(index, [in_val, out_val]))
        # else:
        #     print('These {} values are the same: {}'.format(index, [in_val, out_val]))
# Out:
# /home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/bwh_biopsy.csv /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_biopsy/process_list_autogen.csv
# The seg_level value has differing values for input and output: [-1, 6]
# The vis_level value has differing values for input and output: [-1, 6]
# /home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/bwh_resection.csv /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-bwh_resection/process_list_autogen.csv
# The seg_level value has differing values for input and output: [-1, 6]
# The vis_level value has differing values for input and output: [-1, 6]
# /home/weismanal/notebook/2021-11-10/testing_clam/repo/presets/tcga.csv /home/weismanal/notebook/2021-11-11/testing_clam/RESULTS_DIRECTORY-tcga/process_list_autogen.csv
# The seg_level value has differing values for input and output: [-1, 6]
# The vis_level value has differing values for input and output: [-1, 6]

# %%
output_series
# Out:
# seg_level               6
# sthresh                 8
# mthresh                 7
# close                   4
# use_otsu            False
# keep_ids             none
# exclude_ids          none
# a_t                    16
# a_h                     4
# max_n_holes             8
# vis_level               6
# line_thickness        100
# use_padding          True
# contour_fn        four_pt
# Name: 0, dtype: object

# %%
input_series
# Out:
# seg_level              -1
# sthresh                 8
# mthresh                 7
# close                   4
# use_otsu            False
# a_t                    16
# a_h                     4
# max_n_holes             8
# vis_level              -1
# line_thickness        100
# white_thresh            5
# black_thresh           50
# use_padding          True
# contour_fn        four_pt
# keep_ids             none
# exclude_ids          none
# Name: 0, dtype: object
